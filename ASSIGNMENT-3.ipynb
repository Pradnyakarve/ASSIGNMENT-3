# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
student_list=pd.read_csv('studentlist.csv')

# %%
student_list.head(3)
# Out:
#    enrollmentnumber          admn    studentname  studentEmail
# 0        1613101016  16SCSE101757  AAYUSH  TYAGI           NaN
# 1        1613101026  16SCSE101415       ABHISHEK           NaN
# 2        1613101051  16SCSE101222   ADITI  SINGH           NaN

# %%
student_list.tail(3)
# Out:
#       enrollmentnumber          admn           studentname  studentEmail
# 1014        1613106010  16SCSE106005  SHITIKANT  PRIYANSHU           NaN
# 1015        1613106011  16SCSE106013      SHREYANSH  KUMAR           NaN
# 1016        1613106013  16SCSE106012     SWARNIM  TRIPATHI           NaN

# %%
student_list.drop(columns=['studentEmail','enrollmentnumber','admn'])
# Out:
#                studentname
# 0            AAYUSH  TYAGI
# 1                 ABHISHEK
# 2             ADITI  SINGH
# 3           ADITYA  MANKAR
# 4            AKASH  KANSAL
# ...                    ...
# 1012         PARTH  SHUKLA
# 1013         ROBIN  SHARMA
# 1014  SHITIKANT  PRIYANSHU
# 1015      SHREYANSH  KUMAR
# 1016     SWARNIM  TRIPATHI
#
# [1017 rows x 1 columns]

# %% [markdown]
# Read the folders batchwiselist and quiz

# %%
import os,sys

path=r"C:\Users\Pradnya\Desktop\assignment-3\batchwiselist"
dir = os.listdir(path)
dir

filepath=[]

for file in dir:
    p=path+"/"+file
    csv=pd.read_csv(p)
    filepath.append(csv)
  

batchwise_list=pd.concat(filepath,axis=0,ignore_index=True)
batchwise_list
batchwise_list.drop(columns=['Unnamed: 0','srNo','enrollmentNumber','admissionNumber'])
# Out:
#                  studentName
# 0              AAYUSH  TYAGI
# 1                   ABHISHEK
# 2               ADITI  SINGH
# 3             ADITYA  MANKAR
# 4              AKASH  KANSAL
# ...                      ...
# 1002             SONU  KUMAR
# 1003                   VARUN
# 1004        VISHAL  AGRAHARI
# 1005  VISHAL KUMAR PRAJAPATI
# 1006     ZAYA ALISHAN ANSARI
#
# [1007 rows x 1 columns]

# %%
#os.getcwd()

# %%
#os.getpid()

# %%
quiz1=pd.read_csv(r"C:\Users\Pradnya\Desktop\assignment-3\quiz1.csv")
quiz1.head(3)
# Out:
#       Surname        Firstname ID number Institution Department Email address  \
# 0  16BTCSES11  SIDDHANT  GUPTA       NaN         NaN        NaN           NaN
# 1  16BTCSES11    ARPIT  SHARMA       NaN         NaN        NaN           NaN
# 2  16BTCSES11    VISHAL  SINGH       NaN         NaN        NaN           NaN
#
#       State        Started on         Completed      Time taken Grade/10.00
# 0  Finished  08-02-2019 09:57  08-02-2019 10:11   14 mins 1 sec           4
# 1  Finished  08-02-2019 09:57  08-02-2019 10:11  14 mins 5 secs           5
# 2  Finished  08-02-2019 09:57  14-02-2019 10:10          6 days           7

# %%
quiz1.tail(3)
# Out:
#              Surname     Firstname ID number Institution Department  \
# 657        16BTCSES2  UTTAM  KUMAR       NaN         NaN        NaN
# 658        16BTCSES8   SHREY  JAIN       NaN         NaN        NaN
# 659  Overall average           NaN       NaN         NaN        NaN
#
#                              Email address     State        Started on  \
# 657  uttamkumar@galgotiasuniversity.edu.in  Finished  06-03-2019 07:58
# 658  shrey.jain@galgotiasuniversity.edu.in  Finished  06-03-2019 08:05
# 659                                    NaN       NaN               NaN
#
#             Completed       Time taken Grade/10.00
# 657  06-03-2019 08:14  16 mins 12 secs           4
# 658  06-03-2019 08:10   5 mins 23 secs           4
# 659               NaN              NaN         7.4

# %% [markdown]
# Data cleaning

# %%
quiz1=quiz1.drop(columns=['Surname', 'ID number','Institution','Department','Email address','State','Started on','Completed','Time taken'])

# %%
quiz1
# Out:
#                Firstname Grade/10.00
# 0        SIDDHANT  GUPTA           4
# 1          ARPIT  SHARMA           5
# 2          VISHAL  SINGH           7
# 3           AKASH  YADAV           9
# 4         MANISH  SAHANI           7
# ..                   ...         ...
# 655  ADITYA PRATAP SINGH           2
# 656        Ankita  Singh           2
# 657         UTTAM  KUMAR           4
# 658          SHREY  JAIN           4
# 659                  NaN         7.4
#
# [660 rows x 2 columns]

# %%
quiz2=pd.read_csv(r'C:\Users\Pradnya\Desktop\assignment-3\quiz2.csv')
quiz2
# Out:
#              Surname             Firstname ID number Institution Department  \
# 0          16BTCSES7     VEER SINGH GURJAR       NaN         NaN        NaN
# 1          16BTCSES7        PRANSHU  VERMA       NaN         NaN        NaN
# 2          16BTCSES2          EJAZ  BAKHSH       NaN         NaN        NaN
# 3          16BTCSES7            MOHD  FAIZ       NaN         NaN        NaN
# 4          16BTCSES7          ANISH  SINGH       NaN         NaN        NaN
# ..               ...                   ...       ...         ...        ...
# 676        16BTCSES6  SANJEEV KUMAR PANDEY       NaN         NaN        NaN
# 677        16BTCSES6        UTKARSH  GUPTA       NaN         NaN        NaN
# 678        16BTCSES6          GAURAV  SAHU       NaN         NaN        NaN
# 679        16BTCSES6        MAYANK  DHAWAN       NaN         NaN        NaN
# 680  Overall average                   NaN       NaN         NaN        NaN
#
# ...

# %%
quiz2.drop(columns=['Surname', 'ID number', 'Institution', 'Department',
       'Email address', 'State', 'Started on', 'Completed', 'Time taken'])
# Out:
#                 Firstname Grade/10.00
# 0       VEER SINGH GURJAR           4
# 1          PRANSHU  VERMA          10
# 2            EJAZ  BAKHSH           4
# 3              MOHD  FAIZ          10
# 4            ANISH  SINGH          10
# ..                    ...         ...
# 676  SANJEEV KUMAR PANDEY          10
# 677        UTKARSH  GUPTA          10
# 678          GAURAV  SAHU          10
# 679        MAYANK  DHAWAN          10
# 680                   NaN        8.29
#
# [681 rows x 2 columns]

# %%
quiz1_grades=pd.merge(batchwise_list,quiz1,left_on='studentName',right_on='Firstname')
quiz1_grades
# Out:
#      Unnamed: 0  srNo  enrollmentNumber admissionNumber  \
# 0             0     1        1613101016    16SCSE101757
# 1             1     2        1613101026    16SCSE101415
# 2             2     3        1613101051    16SCSE101222
# 3             3     4        1613101054    16SCSE101220
# 4             7     8        1613101106    16SCSE101520
# ..          ...   ...               ...             ...
# 648          35    36        1613101710    16SCSE101642
# 649          38    39        1613101745    16SCSE101653
# 650          39    40        1613101811    16SCSE101452
# 651          40    41        1613101831    16SCSE101756
# 652          41    42        1613101845    16SCSE101021
#
#                 studentName               Firstname Grade/10.00
# 0             AAYUSH  TYAGI           AAYUSH  TYAGI           5
# 1                  ABHISHEK                ABHISHEK           7
# 2              ADITI  SINGH            ADITI  SINGH           5
# ...

# %%
quiz1_grades.drop(columns=['Unnamed: 0','srNo','enrollmentNumber','admissionNumber','studentName'])
# Out:
#                   Firstname Grade/10.00
# 0             AAYUSH  TYAGI           5
# 1                  ABHISHEK           7
# 2              ADITI  SINGH           5
# 3            ADITYA  MANKAR           7
# 4              Aman  Pandey           5
# ..                      ...         ...
# 648     SHREYASHKAR  SHARMA           4
# 649             SONU  KUMAR           7
# 650                   VARUN           7
# 651        VISHAL  AGRAHARI           7
# 652  VISHAL KUMAR PRAJAPATI           3
#
# [653 rows x 2 columns]

# %%
quiz2_grades=pd.merge(batchwise_list,quiz2,left_on='studentName',right_on='Firstname')
quiz2_grades
# Out:
#      Unnamed: 0  srNo  enrollmentNumber admissionNumber  \
# 0             0     1        1613101016    16SCSE101757
# 1             1     2        1613101026    16SCSE101415
# 2             2     3        1613101051    16SCSE101222
# 3             3     4        1613101054    16SCSE101220
# 4             7     8        1613101106    16SCSE101520
# ..          ...   ...               ...             ...
# 663          34    35        1613101679    16SCSE101166
# 664          38    39        1613101745    16SCSE101653
# 665          39    40        1613101811    16SCSE101452
# 666          40    41        1613101831    16SCSE101756
# 667          41    42        1613101845    16SCSE101021
#
#                 studentName    Surname               Firstname ID number  \
# 0             AAYUSH  TYAGI  16BTCSES1           AAYUSH  TYAGI       NaN
# 1                  ABHISHEK  16BTCSES1                ABHISHEK       NaN
# ...

# %%
quiz2_grades.drop(columns=['Unnamed: 0','srNo','enrollmentNumber','admissionNumber','studentName','Surname','ID number','Institution','Department','Email address','State','Started on','Completed','Time taken'])
# Out:
#                   Firstname Grade/10.00
# 0             AAYUSH  TYAGI          10
# 1                  ABHISHEK          10
# 2              ADITI  SINGH           9
# 3            ADITYA  MANKAR           8
# 4              Aman  Pandey          10
# ..                      ...         ...
# 663         SHIVA  BHARDWAJ           6
# 664             SONU  KUMAR           1
# 665                   VARUN          10
# 666        VISHAL  AGRAHARI           2
# 667  VISHAL KUMAR PRAJAPATI           1
#
# [668 rows x 2 columns]

# %% [markdown]
# Creating DataFrame as per requirement:

# %%
from pandas import DataFrame

# %%
df=pd.DataFrame(columns=["no_of_present", "lessthan50", "between50and60", "between60and70",
"between70and80", "greaterthan80"],index=['Quiz1','Quiz2'])
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           NaN        NaN            NaN            NaN            NaN
# Quiz2           NaN        NaN            NaN            NaN            NaN
#
#       greaterthan80
# Quiz1           NaN
# Quiz2           NaN

# %%
df['no_of_present'][0]=quiz1_grades['studentName'].notnull().sum()
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           653        NaN            NaN            NaN            NaN
# Quiz2           NaN        NaN            NaN            NaN            NaN
#
#       greaterthan80
# Quiz1           NaN
# Quiz2           NaN

# %%
df['no_of_present'][1]=quiz2_grades['studentName'].notnull().sum()
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           653        NaN            NaN            NaN            NaN
# Quiz2           668        NaN            NaN            NaN            NaN
#
#       greaterthan80
# Quiz1           NaN
# Quiz2           NaN

# %%
quiz1_grades['Grade/10.00'].dtype
# Out:
# dtype('O')

# %%
quiz1_grades['Grade/10.00'].sample(10)
# Out:
# 392    10
# 230     6
# 404     9
# 339    10
# 130     6
# 313     4
# 643     8
# 126     9
# 84      4
# 628     4
# Name: Grade/10.00, dtype: object

# %%
quiz1_grades['Grade/10.00']=quiz1_grades['Grade/10.00'].apply(pd.to_numeric,errors='coerce')

quiz1_grades['Grade/10.00'].isna().sum()

quiz1_grades['Grade/10.00'].fillna(0)

quiz1_grades['Grade/10.00'].dtype
# Out:
# dtype('float64')

# %%
lessthan50_1=(quiz1_grades['Grade/10.00']<5).sum()
lessthan50_1
# Out:
# 126

# %%
df.iloc[0,1]=lessthan50_1
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           653        126            NaN            NaN            NaN
# Quiz2           668        NaN            NaN            NaN            NaN
#
#       greaterthan80
# Quiz1           NaN
# Quiz2           NaN

# %%
quiz2_grades['Grade/10.00']=quiz2_grades['Grade/10.00'].apply(pd.to_numeric,errors='coerce')

quiz2_grades['Grade/10.00'].isna().sum()
quiz2_grades['Grade/10.00'].fillna(0)
quiz2_grades['Grade/10.00'].dtype
# Out:
# dtype('float64')

# %%
lessthan50_2=(quiz2_grades['Grade/10.00']<5).sum()
lessthan50_2
# Out:
# 90

# %%
df.iloc[1,1]=lessthan50_2
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           653        126            NaN            NaN            NaN
# Quiz2           668         90            NaN            NaN            NaN
#
#       greaterthan80
# Quiz1           NaN
# Quiz2           NaN

# %%
between50and60_1=quiz1_grades['Grade/10.00'].between(5.1,6,inclusive=True).sum()
between50and60_2=quiz2_grades['Grade/10.00'].between(5.1,6,inclusive=True).sum()

# %%
df.iloc[0,2]=between50and60_1
df.iloc[1,2]=between50and60_2

# %%
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           653        126             57            NaN            NaN
# Quiz2           668         90             37            NaN            NaN
#
#       greaterthan80
# Quiz1           NaN
# Quiz2           NaN

# %%
between60and70_1=quiz1_grades['Grade/10.00'].between(6.1,7,inclusive=True).sum()
between60and70_2=quiz2_grades['Grade/10.00'].between(6.1,7,inclusive=True).sum()

# %%
df.iloc[0,3]=between60and70_1
df.iloc[1,3]=between60and70_2

# %%
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           653        126             57             56            NaN
# Quiz2           668         90             37             40            NaN
#
#       greaterthan80
# Quiz1           NaN
# Quiz2           NaN

# %%
between70and80_1=quiz1_grades['Grade/10.00'].between(7.1,8,inclusive=True).sum()
between70and80_2=quiz2_grades['Grade/10.00'].between(7.1,8,inclusive=True).sum()

# %%
df.iloc[0,4]=between70and80_1
df.iloc[1,4]=between70and80_2

# %%
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           653        126             57             56             41
# Quiz2           668         90             37             40             48
#
#       greaterthan80
# Quiz1           NaN
# Quiz2           NaN

# %%
greaterthan80_1=quiz1_grades['Grade/10.00'].between(8.1,10,inclusive=True).sum()
greaterthan80_2=quiz2_grades['Grade/10.00'].between(8.1,10,inclusive=True).sum()

# %%
df.iloc[0,5]=greaterthan80_1
df.iloc[1,5]=greaterthan80_2

# %%
df
# Out:
#       no_of_present lessthan50 between50and60 between60and70 between70and80  \
# Quiz1           653        126             57             56             41
# Quiz2           668         90             37             40             48
#
#       greaterthan80
# Quiz1           303
# Quiz2           412

# %% [markdown]
# Reading the text case

# %%
TestCase=pd.read_csv(r'C:\Users\Pradnya\Desktop\assignment-3\testcaseStudent.txt')
TestCase
# Out:
#                2
# 0          1.csv
# 1  greaterthan80
# 2          9.csv
# 3     lessthan50

# %%
content=TestCase.iloc[0]
print(content)
content=content[0]
content
# Out:
# 2    1.csv
# Name: 0, dtype: object
# '1.csv'

# %%
for file in dir:
    print(content)
    if(file==content):
        path=r'C:\Users\Pradnya\Desktop\assignment-3\batchwiselist'
        path=path +"/" +file
        csv=pd.read_csv(path)
        break;
    else:
        print("file not found")
csv.head()
csv1=csv
csv1
# Out:
# 1.csv
#     Unnamed: 0  srNo  enrollmentNumber admissionNumber          studentName
# 0            0     1        1613101016    16SCSE101757        AAYUSH  TYAGI
# 1            1     2        1613101026    16SCSE101415             ABHISHEK
# 2            2     3        1613101051    16SCSE101222         ADITI  SINGH
# 3            3     4        1613101054    16SCSE101220       ADITYA  MANKAR
# 4            4     5        1613101079    16SCSE101085        AKASH  KANSAL
# ..         ...   ...               ...             ...                  ...
# 58          58    59        1613101832    16SCSE101071      VISHAL  CHAUHAN
# 59          59    60        1613101850    16SCSE101160         YAMAN  ASWAL
# 60          60    61        1613101853    16SCSE101028          YASH  NIGAM
# 61          61    62        1613101857    16SCSE101547  YASH RAJ SRIVASTAVA
# 62          62    63        1613101861    16SCSE101497       YASHU  CHAUHAN
#
# [63 rows x 5 columns]

# %%
csv1.drop(columns=['Unnamed: 0','srNo','enrollmentNumber','admissionNumber'])
# Out:
#             studentName
# 0         AAYUSH  TYAGI
# 1              ABHISHEK
# 2          ADITI  SINGH
# 3        ADITYA  MANKAR
# 4         AKASH  KANSAL
# ..                  ...
# 58      VISHAL  CHAUHAN
# 59         YAMAN  ASWAL
# 60          YASH  NIGAM
# 61  YASH RAJ SRIVASTAVA
# 62       YASHU  CHAUHAN
#
# [63 rows x 1 columns]

# %%
csv1_quiz1=pd.merge(csv1,quiz1,left_on='studentName',right_on='Firstname')
csv1_quiz1.head()
# Out:
#    Unnamed: 0  srNo  enrollmentNumber admissionNumber     studentName  \
# 0           0     1        1613101016    16SCSE101757   AAYUSH  TYAGI
# 1           1     2        1613101026    16SCSE101415        ABHISHEK
# 2           2     3        1613101051    16SCSE101222    ADITI  SINGH
# 3           3     4        1613101054    16SCSE101220  ADITYA  MANKAR
# 4           7     8        1613101106    16SCSE101520    Aman  Pandey
#
#         Firstname Grade/10.00
# 0   AAYUSH  TYAGI           5
# 1        ABHISHEK           7
# 2    ADITI  SINGH           5
# 3  ADITYA  MANKAR           7
# 4    Aman  Pandey           5

# %%
csv1_quiz1.drop(columns=['Unnamed: 0','srNo','enrollmentNumber','admissionNumber','studentName']).head()
# Out:
#         Firstname Grade/10.00
# 0   AAYUSH  TYAGI           5
# 1        ABHISHEK           7
# 2    ADITI  SINGH           5
# 3  ADITYA  MANKAR           7
# 4    Aman  Pandey           5

# %%
csv1_quiz1['Grade/10.00']=csv1_quiz1['Grade/10.00'].apply(pd.to_numeric,errors='coerce')
csv1_quiz1.count()
# Out:
# Unnamed: 0          46
# srNo                46
# enrollmentNumber    46
# admissionNumber     46
# studentName         46
# Firstname           46
# Grade/10.00         46
# dtype: int64

# %%
greaterthan_80=(csv1_quiz1['Grade/10.00']>8).sum()

# %%
greaterthan_80
# Out:
# 17

# %%
output_txt=pd.DataFrame(index=(1,2),columns=['count'])
output_txt
# Out:
#   count
# 1   NaN
# 2   NaN

# %%
output_txt.loc[1]=greaterthan_80

# %%
output_txt
# Out:
#   count
# 1    17
# 2   NaN

# %% [markdown]
# # csv1_quiz2

# %%
csv1_quiz2=pd.merge(csv1,quiz2,left_on='studentName',right_on='Firstname')
csv1_quiz2.head()
# Out:
#    Unnamed: 0  srNo  enrollmentNumber admissionNumber     studentName  \
# 0           0     1        1613101016    16SCSE101757   AAYUSH  TYAGI
# 1           1     2        1613101026    16SCSE101415        ABHISHEK
# 2           2     3        1613101051    16SCSE101222    ADITI  SINGH
# 3           3     4        1613101054    16SCSE101220  ADITYA  MANKAR
# 4           7     8        1613101106    16SCSE101520    Aman  Pandey
#
#      Surname       Firstname ID number Institution Department  Email address  \
# 0  16BTCSES1   AAYUSH  TYAGI       NaN         NaN        NaN            NaN
# 1  16BTCSES1        ABHISHEK       NaN         NaN        NaN            NaN
# 2  16BTCSES1    ADITI  SINGH       NaN         NaN        NaN            NaN
# 3  16BTCSES1  ADITYA  MANKAR       NaN         NaN        NaN            NaN
# 4  16BTCSES1    Aman  Pandey       NaN         NaN        NaN            NaN
#
#       State        Started on         Completed       Time taken Grade/10.00
# ...

# %%
csv1_quiz2.drop(columns=['Unnamed: 0', 'srNo', 'enrollmentNumber', 'admissionNumber',
        'Surname', 'Firstname', 'ID number', 'Institution',
       'Department', 'Email address', 'State', 'Started on', 'Completed',
       'Time taken' ]).head()
# Out:
#       studentName Grade/10.00
# 0   AAYUSH  TYAGI          10
# 1        ABHISHEK          10
# 2    ADITI  SINGH           9
# 3  ADITYA  MANKAR           8
# 4    Aman  Pandey          10

# %%
csv1_quiz2['Grade/10.00']=csv1_quiz2['Grade/10.00'].apply(pd.to_numeric,errors='coerce')

# %%
csv1_quiz2.head()
# Out:
#    Unnamed: 0  srNo  enrollmentNumber admissionNumber     studentName  \
# 0           0     1        1613101016    16SCSE101757   AAYUSH  TYAGI
# 1           1     2        1613101026    16SCSE101415        ABHISHEK
# 2           2     3        1613101051    16SCSE101222    ADITI  SINGH
# 3           3     4        1613101054    16SCSE101220  ADITYA  MANKAR
# 4           7     8        1613101106    16SCSE101520    Aman  Pandey
#
#      Surname       Firstname ID number Institution Department  Email address  \
# 0  16BTCSES1   AAYUSH  TYAGI       NaN         NaN        NaN            NaN
# 1  16BTCSES1        ABHISHEK       NaN         NaN        NaN            NaN
# 2  16BTCSES1    ADITI  SINGH       NaN         NaN        NaN            NaN
# 3  16BTCSES1  ADITYA  MANKAR       NaN         NaN        NaN            NaN
# 4  16BTCSES1    Aman  Pandey       NaN         NaN        NaN            NaN
#
#       State        Started on         Completed       Time taken  Grade/10.00
# ...

# %%
(csv1_quiz2['Grade/10.00']<5).sum()
# Out:
# 4

# %%
lessthan_5=(csv1_quiz2['Grade/10.00']<5).sum()

# %%
output_txt.loc[2]=lessthan_5

# %%
output_txt
# Out:
#   count
# 1    17
# 2     4

# %% [markdown]
# # Create file Output1_txt

# %%
with open(r'C:\Users\Pradnya\Desktop\output1.txt','w') as f :
    f.write(output_txt.to_csv(header=True,index=True))

# %%
ex=pd.read_csv(r'C:\Users\Pradnya\Desktop\output1.txt')

# %%
ex
# Out:
#    Unnamed: 0  count
# 0           1     17
# 1           2      4

# %% [markdown]
# # csv9_quiz1

# %%
TestCase
# Out:
#                2
# 0          1.csv
# 1  greaterthan80
# 2          9.csv
# 3     lessthan50

# %%
content2=TestCase.iloc[2]
content2=content2[0]
a=content2
a
# Out:
# '9.csv'

# %%
for file in dir:
    if(file==a):
        print('File Found',file)
        path=r'C:\Users\Pradnya\Desktop\assignment-3\batchwiselist'
        path=path+'/'+file
        csv=pd.read_csv(path)
        break;
else:
    print('File Not Found')
csv9=csv
# Out:
# File Found 9.csv

# %%
csv9.drop(columns=['Unnamed: 0','srNo','enrollmentNumber','admissionNumber']).head()
# Out:
#            studentName
# 0              AANCHAL
# 1               ADARSH
# 2   AKASH KUMAR SAHANI
# 3  ANAND KUMAR JAISWAL
# 4       ANIRUDH  SINGH

# %%
csv9['studentName'].value_counts().sum()
# Out:
# 39

# %%
csv9_quiz1=pd.merge(csv9,quiz1,left_on='studentName',right_on='Firstname')

# %%
csv9_quiz1=csv9_quiz1.drop(columns=['Unnamed: 0','srNo','enrollmentNumber','admissionNumber','studentName'])

# %%
csv9_quiz1
# Out:
#                  Firstname Grade/10.00
# 0                  AANCHAL           4
# 1       AKASH KUMAR SAHANI          10
# 2           ANIRUDH  SINGH           5
# 3            ANKITA  YADAV          10
# 4              ANURAG  RAI          10
# 5             AYUSH  TYAGI           5
# 6       MAYANK  SRIVASTAVA           7
# 7           MOHAMMAD  ASIM           8
# 8      PARAG  VIJAYVARGIYA           9
# 9             Poonam Singh          10
# 10        prajjwal  pandey           4
# 11          Prajwal  Joshi           9
# 12    RAVINDRA KUMAR YADAV           8
# 13           SATYAM  YADAV           4
# 14         SAURABH  BAJPAI           5
# 15         SHANTANU  SINGH           0
# 16         SHIVA  BHARDWAJ           9
# 17     SHREYASHKAR  SHARMA           4
# 18             SONU  KUMAR           7
# 19                   VARUN           7
# 20        VISHAL  AGRAHARI           7
# 21  VISHAL KUMAR PRAJAPATI           3

# %%
csv9_quiz1['Grade/10.00']=csv9_quiz1['Grade/10.00'].apply(pd.to_numeric,errors='coerce')

# %%
(csv9_quiz1['Grade/10.00']<5).sum()
# Out:
# 6

# %%
b=(csv9_quiz1['Grade/10.00']<5).sum()
b
# Out:
# 6

# %%
output_txt2=pd.DataFrame(index=[1,2],columns=['count'])

# %%
output_txt2
# Out:
#   count
# 1   NaN
# 2   NaN

# %%
output_txt2.iloc[0]=b

# %%
output_txt2
# Out:
#   count
# 1     6
# 2   NaN

# %%
csv9_quiz2=pd.merge(csv9,quiz2,left_on='studentName',right_on='Firstname')

# %%
csv9_quiz2=csv9_quiz2.drop(columns=['Unnamed: 0', 'srNo', 'enrollmentNumber', 'admissionNumber',
       'studentName', 'Surname', 'ID number', 'Institution',
       'Department', 'Email address', 'State', 'Started on', 'Completed',
       'Time taken', ])

# %%
csv9_quiz2['Grade/10.00'].value_counts().sum()
# Out:
# 22

# %%
csv9_quiz2['Grade/10.00']=csv9_quiz2['Grade/10.00'].apply(pd.to_numeric,errors='coerce')

# %%
(csv9_quiz2['Grade/10.00']<5).sum()
# Out:
# 12

# %%
c=(csv9_quiz2['Grade/10.00']<5).sum()

# %%
c
# Out:
# 12

# %%
output_txt2.iloc[1]=c

# %%
output_txt2
# Out:
#   count
# 1     6
# 2    12

# %%
with open(r'C:\Users\Pradnya\Desktop\assignment-3\output2.txt','w') as f:
    f.write(output_txt2.to_csv(header=True,index=True))
